# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("temp_output (1).csv")

# %%
df
# Out:
#        Unnamed: 0        area     price  building_state   facades  bedrooms  \
# 0               0  123.000000  200000.0            good  3.000000       2.0
# 1               1  255.000000  698000.0  just renovated  4.000000       4.0
# 2               2  234.000000  499000.0          as new  2.970242       5.0
# 3               3  219.000000  717000.0          as new  2.970242       4.0
# 4               4  156.000000  429000.0            good  4.000000       4.0
# ...           ...         ...       ...             ...       ...       ...
# 10053       10087  234.560062  330000.0  just renovated  2.970242       5.0
# 10054       10088  135.000000   75000.0            good  2.000000       2.0
# 10055       10089  107.000000  165239.0          as new  4.000000       2.0
# 10056       10090  200.000000  580000.0          as new  4.000000       3.0
# 10057       10091  234.560062  219000.0            good  2.970242       2.0
#
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                  Unnamed: 0      area     price   facades  bedrooms  \
# Unnamed: 0         1.000000  0.008424  0.012088 -0.010208  0.002777
# area               0.008424  1.000000  0.519458  0.160874  0.487949
# price              0.012088  0.519458  1.000000  0.222897  0.422251
# facades           -0.010208  0.160874  0.222897  1.000000  0.117986
# bedrooms           0.002777  0.487949  0.422251  0.117986  1.000000
# furnished         -0.013888  0.076690  0.023466  0.015390  0.036040
# open_fire          0.006095  0.116961  0.050870  0.025646  0.066557
# locality          -0.004621 -0.130595 -0.246955 -0.054209 -0.143810
# land_surface       0.008494  0.189322  0.221304  0.084804  0.141928
# terrace           -0.003210  0.011665  0.091398 -0.014474  0.054837
# terrace_surface   -0.002107  0.019294  0.024026  0.003846  0.023638
# swimming_pool     -0.006194  0.244128  0.403812  0.218873  0.153696
# garden             0.008833  0.012764  0.068513  0.005296  0.050694
# ...

# %%
#df_us = pd.read_csv("final_list_houses_dataset.csv")
#df_us

# %%
#sns.heatmap(df_us.corr())

# %%
#df_us.info()

# %%
#df.value_counts()

# %%
#df.value_counts().isna()

# %%
df.drop(columns="property_type")
# Out:
#        Unnamed: 0        area     price  building_state   facades  bedrooms  \
# 0               0  123.000000  200000.0            good  3.000000       2.0
# 1               1  255.000000  698000.0  just renovated  4.000000       4.0
# 2               2  234.000000  499000.0          as new  2.970242       5.0
# 3               3  219.000000  717000.0          as new  2.970242       4.0
# 4               4  156.000000  429000.0            good  4.000000       4.0
# ...           ...         ...       ...             ...       ...       ...
# 10053       10087  234.560062  330000.0  just renovated  2.970242       5.0
# 10054       10088  135.000000   75000.0            good  2.000000       2.0
# 10055       10089  107.000000  165239.0          as new  4.000000       2.0
# 10056       10090  200.000000  580000.0          as new  4.000000       3.0
# 10057       10091  234.560062  219000.0            good  2.970242       2.0
#
# ...

# %%
df.property_subtype.value_counts()
# Out:
# house          7438
# villa          1139
# mixed           306
# apartment       293
# exceptional     254
# mansion         181
# country         102
# town             99
# bungalow         72
# building         62
# farmhouse        42
# manor            22
# castle           17
# other            17
# chalet           13
# land              1
# Name: property_subtype, dtype: int64

# %%
df = df[df.property_subtype != "land"]

# %%
df.property_subtype.value_counts()
# Out:
# house          7438
# villa          1139
# mixed           306
# apartment       293
# exceptional     254
# mansion         181
# country         102
# town             99
# bungalow         72
# building         62
# farmhouse        42
# manor            22
# castle           17
# other            17
# chalet           13
# Name: property_subtype, dtype: int64

# %% [markdown]
# REGRESSION

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

x = df[["area", "bedrooms"]].values
y = df["price"].values

# %%
#multiple linear regression

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

print(regressor.score(X_train, y_train))
print(regressor.score(x, y))
# Out:
# 0.3093019281187718
# 0.30696582229951996

# %%
#polynomial regression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# creating pipeline
Input = [('polynomial',PolynomialFeatures(degree=3)),('modal',LinearRegression())]
pipe = Pipeline(Input)

pipe.fit(X_train, y_train)
poly_pred = pipe.predict(X_test)

print(pipe.score(X_train, y_train))
print(pipe.score(X_test, y_test))
# Out:
# 0.47498041880491093
# 0.3752406473164085

# %%
df[df['price'] > 1000000].value_counts().sum()
df_copy = df.copy()
df_copy['price'] = df['price'] < 1000000

# %%
x = df_copy[["area", "bedrooms"]].values
y = df_copy["price"].values

#polynomial regression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# creating pipeline
Input = [('polynomial',PolynomialFeatures(degree=4)),('modal',LinearRegression())]
pipe = Pipeline(Input)

pipe.fit(X_train, y_train)
poly_pred = pipe.predict(X_test)

print(pipe.score(X_train, y_train))
print(pipe.score(X_test, y_test))
# Out:
# 0.36297123509221707
# 0.345141633528113

# %%
#multiple linear regression

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

print(regressor.score(X_train, y_train))
print(regressor.score(x, y))
# Out:
# 0.22982604329348266
# 0.2332566148672729

# %%
df_copy.bedrooms.value_counts()
# Out:
# 3.00000     4450
# 4.00000     2351
# 2.00000     1148
# 5.00000      989
# 6.00000      401
# 1.00000      177
# 7.00000      155
# 3.65166      150
# 8.00000       91
# 10.00000      47
# 9.00000       41
# 11.00000      18
# 12.00000      10
# 15.00000       5
# 16.00000       4
# 13.00000       3
# 14.00000       3
# 22.00000       3
# 41.00000       2
# 30.00000       2
# 18.00000       2
# 39.00000       1
# 20.00000       1
# 50.00000       1
# 32.00000       1
# 24.00000       1
# Name: bedrooms, dtype: int64

# %%
df_copy.property_subtype.value_counts()
# Out:
# True     9988
# False      69
# Name: property_subtype, dtype: int64

# %%
list_properties = ['house', 'villa', 'mixed', 'apartment', 'exceptional', 'mansion',
                   'country', 'town', 'bungalow', 'building', 'farmhouse']
df_copy['property_subtype'] = df_copy['property_subtype'] == [['house', 'villa', 'mixed', 'apartment', 'exceptional', 'mansion',
                   'country', 'town', 'bungalow', 'building', 'farmhouse']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-95cb77c7def6> in <module>
#       1 list_properties = ['house', 'villa', 'mixed', 'apartment', 'exceptional', 'mansion',
#       2                    'country', 'town', 'bungalow', 'building', 'farmhouse']
# ----> 3 df_copy['property_subtype'] = df_copy['property_subtype'] == [['house', 'villa', 'mixed', 'apartment', 'exceptional', 'mansion',
#       4                    'country', 'town', 'bungalow', 'building', 'farmhouse']]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
# ...

# %%
df_copy.property_subtype.value_counts()
# Out:
# True     9988
# False      69
# Name: property_subtype, dtype: int64
